# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv(r'C:\Users\UTILISATEUR\Desktop\Borel\flightlist_20191201_20191231.csv')

# %%
df4 = pd.read_csv (r'C:\Users\UTILISATEUR\Desktop\Borel\flightlist_20200301_20200331.csv')

# %%
df2 = pd.read_csv(r'C:\Users\UTILISATEUR\Desktop\Borel\flightlist_20200101_20200131.csv')

# %%
df3 = pd.read_csv ( r'C:\Users\UTILISATEUR\Desktop\Borel\flightlist_20200201_20200229.csv')

# %%
flight = df1.append(df2, ignore_index=True)

# %%
flight = flight.append(df3, ignore_index=True)

# %%
flight = flight.append(df4, ignore_index=True)

# %%
flight
# Out:
#          callsign number  icao24 registration typecode origin destination  \
# 0          THY183    NaN  4ba9c2       TC-JNB     A332    NaN        LTBW
# 1           HVN19   VN19  888167          NaN      NaN   YMML        LFPG
# 2          CES201    NaN  780b33       B-5930     A332   YMML        EGKK
# 3          KQA210  KQ210  04c148       5Y-CYB     B738   FAOR        VABB
# 4          MAU851    NaN  06002a       3B-NBL     A332   VABB        FAOR
# ...           ...    ...     ...          ...      ...    ...         ...
# 10237073      RCR    NaN  7c5669          NaN      NaN   YLIL        YMEN
# 10237074   CTV792  QG792  8a061d       PK-GQS     A320    NaN         NaN
# 10237075   N89963    NaN  ac6a09       N89963      NaN   57CN        KSAC
# 10237076   N124TX    NaN  a0644d       N124TX     AS50   6TE0        TS05
# 10237077   CAL511  CI511  899018      B-18052     B77W   RCTP         NaN
#
#                           firstseen                   lastseen  \
# ...

# %%
flight_copy = flight.copy

# %%
flight.drop(["callsign","number", "icao24" ,"registration", "typecode"], axis = 1, inplace = True )

# %%
flight
# Out:
#          origin destination                  firstseen  \
# 0           NaN        LTBW  2019-11-30 00:11:15+00:00
# 1          YMML        LFPG  2019-11-30 00:57:39+00:00
# 2          YMML        EGKK  2019-11-30 01:19:12+00:00
# 3          FAOR        VABB  2019-11-30 01:46:07+00:00
# 4          VABB        FAOR  2019-11-30 01:46:50+00:00
# ...         ...         ...                        ...
# 10237073   YLIL        YMEN  2020-03-31 23:43:47+00:00
# 10237074    NaN         NaN  2020-03-31 23:43:58+00:00
# 10237075   57CN        KSAC  2020-03-31 23:44:24+00:00
# 10237076   6TE0        TS05  2020-03-31 23:47:05+00:00
# 10237077   RCTP         NaN  2020-03-31 23:48:04+00:00
#
#                            lastseen                        day  latitude_1  \
# 0         2019-12-01 08:12:17+00:00  2019-12-01 00:00:00+00:00   41.181879
# 1         2019-12-01 05:10:22+00:00  2019-12-01 00:00:00+00:00  -37.680222
# 2         2019-12-01 05:37:59+00:00  2019-12-01 00:00:00+00:00  -37.685989
# ...

# %%
flight.drop(["latitude_1","longitude_1", "altitude_1", "latitude_2", "longitude_2", "altitude_2"], axis = 1, inplace = True )

# %%
flight
# Out:
#          origin destination                  firstseen  \
# 0           NaN        LTBW  2019-11-30 00:11:15+00:00
# 1          YMML        LFPG  2019-11-30 00:57:39+00:00
# 2          YMML        EGKK  2019-11-30 01:19:12+00:00
# 3          FAOR        VABB  2019-11-30 01:46:07+00:00
# 4          VABB        FAOR  2019-11-30 01:46:50+00:00
# ...         ...         ...                        ...
# 10237073   YLIL        YMEN  2020-03-31 23:43:47+00:00
# 10237074    NaN         NaN  2020-03-31 23:43:58+00:00
# 10237075   57CN        KSAC  2020-03-31 23:44:24+00:00
# 10237076   6TE0        TS05  2020-03-31 23:47:05+00:00
# 10237077   RCTP         NaN  2020-03-31 23:48:04+00:00
#
#                            lastseen                        day
# 0         2019-12-01 08:12:17+00:00  2019-12-01 00:00:00+00:00
# 1         2019-12-01 05:10:22+00:00  2019-12-01 00:00:00+00:00
# 2         2019-12-01 05:37:59+00:00  2019-12-01 00:00:00+00:00
# ...

# %%
flight['day'] = pd.to_datetime(flight['day'], infer_datetime_format=True)

# %%
flight
# Out:
#          origin destination                  firstseen  \
# 0           NaN        LTBW  2019-11-30 00:11:15+00:00
# 1          YMML        LFPG  2019-11-30 00:57:39+00:00
# 2          YMML        EGKK  2019-11-30 01:19:12+00:00
# 3          FAOR        VABB  2019-11-30 01:46:07+00:00
# 4          VABB        FAOR  2019-11-30 01:46:50+00:00
# ...         ...         ...                        ...
# 10237073   YLIL        YMEN  2020-03-31 23:43:47+00:00
# 10237074    NaN         NaN  2020-03-31 23:43:58+00:00
# 10237075   57CN        KSAC  2020-03-31 23:44:24+00:00
# 10237076   6TE0        TS05  2020-03-31 23:47:05+00:00
# 10237077   RCTP         NaN  2020-03-31 23:48:04+00:00
#
#                            lastseen                       day
# 0         2019-12-01 08:12:17+00:00 2019-12-01 00:00:00+00:00
# 1         2019-12-01 05:10:22+00:00 2019-12-01 00:00:00+00:00
# 2         2019-12-01 05:37:59+00:00 2019-12-01 00:00:00+00:00
# ...

# %%
flight["day"] = flight["day"].dt.date

# %%
flight
# Out:
#          origin destination                  firstseen  \
# 0           NaN        LTBW  2019-11-30 00:11:15+00:00
# 1          YMML        LFPG  2019-11-30 00:57:39+00:00
# 2          YMML        EGKK  2019-11-30 01:19:12+00:00
# 3          FAOR        VABB  2019-11-30 01:46:07+00:00
# 4          VABB        FAOR  2019-11-30 01:46:50+00:00
# ...         ...         ...                        ...
# 10237073   YLIL        YMEN  2020-03-31 23:43:47+00:00
# 10237074    NaN         NaN  2020-03-31 23:43:58+00:00
# 10237075   57CN        KSAC  2020-03-31 23:44:24+00:00
# 10237076   6TE0        TS05  2020-03-31 23:47:05+00:00
# 10237077   RCTP         NaN  2020-03-31 23:48:04+00:00
#
#                            lastseen         day
# 0         2019-12-01 08:12:17+00:00  2019-12-01
# 1         2019-12-01 05:10:22+00:00  2019-12-01
# 2         2019-12-01 05:37:59+00:00  2019-12-01
# 3         2019-12-01 10:43:44+00:00  2019-12-01
# 4         2019-12-01 09:29:13+00:00  2019-12-01
# ...

# %%
 flight_day = flight[(flight['day'] > '2019-12-18') & (flight['day'] <= '2020-03-15')]

# %%
flight_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7899977 entries, 1456894 to 9361838
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   origin       object
#  1   destination  object
#  2   firstseen    object
#  3   lastseen     object
#  4   day          object
# dtypes: object(5)
# memory usage: 361.6+ MB

# %%
 flight_day
# Out:
#         origin destination                  firstseen  \
# 1456894   KBNG        KPSP  2019-12-18 00:00:03+00:00
# 1456895    NaN        KBFI  2019-12-18 00:00:03+00:00
# 1456896    NaN        KSAT  2019-12-18 00:00:03+00:00
# 1456897    NaN        EGSS  2019-12-18 00:00:03+00:00
# 1456898    NaN        KCMH  2019-12-18 00:00:03+00:00
# ...        ...         ...                        ...
# 9361733   WSSS         NaN  2020-03-14 23:45:56+00:00
# 9361757   OERK         NaN  2020-03-14 23:46:21+00:00
# 9361768   KSEE        KSEE  2020-03-14 23:46:43+00:00
# 9361778    NaN         NaN  2020-03-14 23:46:54+00:00
# 9361838    NaN         NaN  2020-03-14 23:48:13+00:00
#
#                           lastseen                        day
# 1456894  2019-12-18 00:12:36+00:00  2019-12-18 00:00:00+00:00
# 1456895  2019-12-18 00:12:29+00:00  2019-12-18 00:00:00+00:00
# 1456896  2019-12-18 03:42:42+00:00  2019-12-18 00:00:00+00:00
# 1456897  2019-12-18 00:12:28+00:00  2019-12-18 00:00:00+00:00
# ...

# %%
flight_day['Date'] = pd.to_datetime(flight_day['day'], infer_datetime_format=True)
# Out:
# <ipython-input-152-9711c74120f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flight_day['Date'] = pd.to_datetime(flight_day['day'], infer_datetime_format=True)

# %%
flight_day['Date'] = flight_day['Date'].dt.date
# Out:
# <ipython-input-153-4d30b827bff3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flight_day['Date'] = flight_day['Date'].dt.date

# %%
flight_day.drop(["day"], axis = 1, inplace = True )
# Out:
# C:\Users\UTILISATEUR\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
flight_day
# Out:
#         origin destination                  firstseen  \
# 1456894   KBNG        KPSP  2019-12-18 00:00:03+00:00
# 1456895    NaN        KBFI  2019-12-18 00:00:03+00:00
# 1456896    NaN        KSAT  2019-12-18 00:00:03+00:00
# 1456897    NaN        EGSS  2019-12-18 00:00:03+00:00
# 1456898    NaN        KCMH  2019-12-18 00:00:03+00:00
# ...        ...         ...                        ...
# 9361733   WSSS         NaN  2020-03-14 23:45:56+00:00
# 9361757   OERK         NaN  2020-03-14 23:46:21+00:00
# 9361768   KSEE        KSEE  2020-03-14 23:46:43+00:00
# 9361778    NaN         NaN  2020-03-14 23:46:54+00:00
# 9361838    NaN         NaN  2020-03-14 23:48:13+00:00
#
#                           lastseen        Date
# 1456894  2019-12-18 00:12:36+00:00  2019-12-18
# 1456895  2019-12-18 00:12:29+00:00  2019-12-18
# 1456896  2019-12-18 03:42:42+00:00  2019-12-18
# 1456897  2019-12-18 00:12:28+00:00  2019-12-18
# 1456898  2019-12-18 01:23:43+00:00  2019-12-18
# ...

# %%
flight_day = flight_day.sample(39000)
flight_day
# Out:
#         origin destination                  firstseen  \
# 5656427   KATL        KEWR  2020-02-03 14:13:30+00:00
# 2055901   KLAX        KCVG  2019-12-24 04:15:51+00:00
# 8937525   RJBB         NaN  2020-03-10 04:39:56+00:00
# 6393315   KX49        KLAL  2020-02-11 20:32:30+00:00
# 9070711   EBBR        ESSA  2020-03-11 17:05:13+00:00
# ...        ...         ...                        ...
# 1909174   VECC        VIDP  2019-12-22 15:39:04+00:00
# 3545185   KATW        KDTW  2020-01-10 12:58:45+00:00
# 1547040   CYYC         NaN  2019-12-18 20:57:39+00:00
# 3944787   KLAX        KPDX  2020-01-15 04:53:54+00:00
# 2998802   EHRD         NaN  2020-01-04 12:06:49+00:00
#
#                           lastseen        Date
# 5656427  2020-02-03 15:54:58+00:00  2020-02-03
# 2055901  2019-12-24 07:37:02+00:00  2019-12-24
# 8937525  2020-03-10 05:15:27+00:00  2020-03-10
# 6393315  2020-02-11 21:18:47+00:00  2020-02-11
# 9070711  2020-03-11 18:58:45+00:00  2020-03-11
# ...

# %%
# task 3 // a continuer...   filtrage ok , reste a sample  39 K  puis a

# %%
covid_19 =  pd.read_csv(r"C:\Users\UTILISATEUR\Desktop\Borel\CVD-19.csv")

# %%
covid_19
# Out:
#             Country  New_cases  Cumulative_cases  New_deaths  \
# 0       Afghanistan          0                 0           0
# 1       Afghanistan          0                 0           0
# 2       Afghanistan          0                 0           0
# 3       Afghanistan          0                 0           0
# 4       Afghanistan          0                 0           0
# ...             ...        ...               ...         ...
# 165658     Zimbabwe         62            133836           0
# 165659     Zimbabwe        115            133951           1
# 165660     Zimbabwe         40            133991           0
# 165661     Zimbabwe        235            134226           1
# 165662     Zimbabwe        426            134652           1
#
#         Cumulative_deaths       Date
# 0                       0 2020-01-03
# 1                       0 2020-01-04
# 2                       0 2020-01-05
# 3                       0 2020-01-06
# 4                       0 2020-01-07
# ...

# %%
covid_19['Date'] = pd.to_datetime(covid_19['Date_reported'], infer_datetime_format=True)

# %%
#  des 10 premiers pays les plus touché covid 19
covid_most_affected1 = covid_19[covid_19["Date"] == "2020-05-29"].groupby("Country", as_index=False)["Cumulative_cases"].sum().sort_values("Cumulative_cases", ascending=False)

# %%
# Out:
#                       Country  Cumulative_cases
# 226  United States of America           1740633
# 28                     Brazil            411821
# 173        Russian Federation            387623
# 210        The United Kingdom            250586
# 201                     Spain            243823
# ..                        ...               ...
# 144                     Nauru                 0
# 178              Saint Helena                 0
# 165          Pitcairn Islands                 0
# 159                     Palau                 0
# 184                     Samoa                 0
#
# [237 rows x 2 columns]

# %%
covid_19[(covid_19["Country"] == "Germany") & (covid_19["Date"] == "2020-05-29")]
# Out:
#        Country  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# 54669  Germany        741            180458          39               8450
#
#             Date
# 54669 2020-05-29

# %%
covid_19.drop(["WHO_region","Date_reported","Country_code"], axis = 1 , inplace = True)

# %%
covid_19
# Out:
#             Country  New_cases  Cumulative_cases  New_deaths  \
# 0       Afghanistan          0                 0           0
# 1       Afghanistan          0                 0           0
# 2       Afghanistan          0                 0           0
# 3       Afghanistan          0                 0           0
# 4       Afghanistan          0                 0           0
# ...             ...        ...               ...         ...
# 165658     Zimbabwe         62            133836           0
# 165659     Zimbabwe        115            133951           1
# 165660     Zimbabwe         40            133991           0
# 165661     Zimbabwe        235            134226           1
# 165662     Zimbabwe        426            134652           1
#
#         Cumulative_deaths       Date
# 0                       0 2020-01-03
# 1                       0 2020-01-04
# 2                       0 2020-01-05
# 3                       0 2020-01-06
# 4                       0 2020-01-07
# ...

# %%
covid_19.to_csv(r"C:/Users/UTILISATEUR/Desktop/Borel/covdbi.csv")

# %%
covid_19.to_

# %%
covid_copy = covid_19.copy() # Copy ya original dataset covid

# %%
covid_19 = covid_19[(covid_19['Date'] > '2019-12-18') & (covid_19['Date'] <= '2020-03-15')]

# %%
covid_19
# Out:
#             Country  New_cases  Cumulative_cases  New_deaths  \
# 0       Afghanistan          0                 0           0
# 1       Afghanistan          0                 0           0
# 2       Afghanistan          0                 0           0
# 3       Afghanistan          0                 0           0
# 4       Afghanistan          0                 0           0
# ...             ...        ...               ...         ...
# 165032     Zimbabwe          0                 0           0
# 165033     Zimbabwe          0                 0           0
# 165034     Zimbabwe          0                 0           0
# 165035     Zimbabwe          0                 0           0
# 165036     Zimbabwe          0                 0           0
#
#         Cumulative_deaths       Date
# 0                       0 2020-01-03
# 1                       0 2020-01-04
# 2                       0 2020-01-05
# 3                       0 2020-01-06
# 4                       0 2020-01-07
# ...

# %%
covid_copy = covid_copy[(covid_copy['Date'] > '2020-03-16') & (covid_copy['Date'] <= '2020-05-29')]

# %%
covid_copy
# Out:
#             Country  New_cases  Cumulative_cases  New_deaths  \
# 74      Afghanistan         -1                24           0
# 75      Afghanistan          0                24           0
# 76      Afghanistan          0                24           0
# 77      Afghanistan          0                24           0
# 78      Afghanistan          0                24           0
# ...             ...        ...               ...         ...
# 165107     Zimbabwe          0                56           0
# 165108     Zimbabwe          0                56           0
# 165109     Zimbabwe          0                56           0
# 165110     Zimbabwe         76               132           0
# 165111     Zimbabwe          0               132           0
#
#         Cumulative_deaths       Date
# 74                      0 2020-03-17
# 75                      0 2020-03-18
# 76                      0 2020-03-19
# 77                      0 2020-03-20
# 78                      0 2020-03-21
# ...

# %%
covid_copy.to_csv(r"C:/Users/UTILISATEUR/Desktop/Borel/covid_till_mai.csv")

# %%
#  des 10 premiers pays les plus touché covid 19
covid_most_affected = covid_19[covid_19["Date"] == "2020-03-15"].groupby("Country", as_index=False)["Cumulative_cases"].sum().sort_values("Cumulative_cases", ascending=False).head(10)

# %%
covid_most_affected
# Out:
#                         Country  Cumulative_cases
# 42                        China             81048
# 103                       Italy             21157
# 98   Iran (Islamic Republic of)             13987
# 201                       Spain              8523
# 170           Republic of Korea              8162
# 72                       France              4436
# 226    United States of America              3909
# 78                      Germany              3795
# 206                 Switzerland              2372
# 210          The United Kingdom              2253

# %% [markdown]
# ### 10 most affected countries on march 15th

# %%
covid_19[covid_19["Date"] == "2020-03-15"].groupby("Country", as_index=True)['Cumulative_cases'].sum().sort_values(ascending=False).head(10).plot(kind='barh')

# %%
covid_19["Country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
country1 = 'China'

covid_19[covid_19["Country"] == country1].plot(x = "Date", y = "Cumulative_cases")

country2 = 'Iran (Islamic Republic of)'

covid_19[covid_19["Country"] == country2].plot(x = "Date", y = "Cumulative_cases")

country3 = 'Italy'

covid_19[covid_19["Country"] == country3].plot(x = "Date", y = "Cumulative_cases")

country4 = 'Republic of Korea'

covid_19[covid_19["Country"] == country4].plot(x = "Date", y = "Cumulative_cases")

country5 = 'France'

covid_19[covid_19["Country"] == country5].plot(x = "Date", y = "Cumulative_cases")

country6 = 'Spain'

covid_19[covid_19["Country"] == country6].plot(x = "Date", y = "Cumulative_cases")

country7 = 'Germany'

covid_19[covid_19["Country"] == country7].plot(x = "Date", y = "Cumulative_cases")

country8 = 'United States of America'

covid_19[covid_19["Country"] == country8].plot(x = "Date", y = "Cumulative_cases")

country9 = 'Switzerland'

covid_19[covid_19["Country"] == country9].plot(x = "Date", y = "Cumulative_cases")

country10 = 'The United Kingdom'

covid_19[covid_19["Country"] == country10].plot(x = "Date", y = "Cumulative_cases")

# %%
#  des 10 derniers pays les moins touché covid 19
covid_most_affected2 = covid_19[covid_19["Date"] == "2020-03-15"].groupby("Country", as_index=False)["Cumulative_cases"].sum().sort_values("Cumulative_cases", ascending=True).head(70)

# %%
covid_most_affected2
# Out:
#                        Country  Cumulative_cases
# 118                    Liberia                 0
# 182  Saint Pierre and Miquelon                 0
# 184                      Samoa                 0
# 186      Sao Tome and Principe                 0
# 191               Sierra Leone                 0
# 193             Sint Eustatius                 0
# 91                       Haiti                 0
# 89               Guinea-Bissau                 0
# 85                        Guam                 0
# 83                     Grenada                 0

# %%
covid_alpha  =  pd.read_csv(r"C:\Users\UTILISATEUR\Desktop\Borel\cvdq.csv")

# %%
covid_alpha['Date'] = pd.to_datetime(covid_19['Date'], infer_datetime_format=True)

# %%
covid_alpha
# Out:
#        Unnamed: 0 Origin Country/Region        Firstseen         Lastseen  \
# 0               0  China         Taiwan  12/20/2019 0:43  12/20/2019 1:50
# 1               1  China         Taiwan  12/20/2019 1:02  12/20/2019 2:29
# 2               2  China         Taiwan  12/20/2019 1:26  12/20/2019 2:33
# 3               3  China         Taiwan  12/20/2019 1:46  12/20/2019 2:55
# 4               4  China         Taiwan  12/20/2019 2:05  12/20/2019 3:11
# ...           ...    ...            ...              ...              ...
# 38815       38815  China        Austria   3/14/2020 2:33  3/14/2020 15:57
# 38816       38816  China         Turkey  3/14/2020 11:36  3/14/2020 22:39
# 38817       38817  China      Sri Lanka  3/14/2020 13:22  3/14/2020 18:38
# 38818       38818  China        Bahrain  3/14/2020 22:00   3/15/2020 6:49
# 38819       38819  China        Bahrain  3/14/2020 23:19   3/15/2020 8:02
#
#           Date Air_traffic       Date  Confirmed  Recovered  Deaths
# ...

# %%
#  des 10 premiers pays les plus touché covid alpha
covid_most_affected_alpha = covid_alpha[covid_alpha["Date"] == "2020-03-15"].groupby("Country/Region", as_index=False)["Confirmed"].sum().sort_values("Confirmed", ascending=False).head(10)

# %%
covid_alpha["Country/Region"].unique()
# Out:
# array(['Taiwan', 'USA', 'Thailand', nan, 'Japan', 'South Korea',
#        'Malaysia', 'Singapore', 'Australia', 'Philippines', 'India',
#        'United Kingdom', 'United Arab Emirates', 'Canada', 'Germany',
#        'New Zealand', 'Russia', 'Netherlands', 'Switzerland', 'France',
#        'Belgium', 'Finland', 'Kazakhstan', 'Spain', 'Italy',
#        'Brunei Darussalam', 'Luxembourg', 'Saudi Arabia', 'Hungary',
#        'Austria', 'Brazil', 'Sri Lanka', 'Denmark', 'Czech Republic',
#        'Israel', 'Vietnam', 'Uzbekistan', 'South Africa', 'Turkey',
#        'Sweden', 'Bahrain', 'Mexico', 'Nepal', 'Greece', 'Poland',
#        'Malta', 'Ireland', 'Latvia'], dtype=object)

# %%
covid_most_affected_alpha
# Out:
#     Country/Region  Confirmed
# 6            Japan      141.0
# 0        Australia       74.0
# 14        Thailand       49.0
# 17  United Kingdom       19.0
# 7         Malaysia        8.0
# 5            India        3.0
# 11       Singapore        3.0
# 3           Canada        2.0
# 10     Philippines        2.0
# 4           France        0.0

# %%
### Covid alpha les 10 pays les plus touchés

# %%
covid_alpha[covid_alpha["Date"] == "2020-03-15"].groupby("Country/Region", as_index=True)['Confirmed'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
country1 = 'Japan'

covid_alpha[covid_alpha["Country/Region"] == country1].plot(x = "Date", y = "Confirmed")

country2 = 'Australia'

covid_alpha[covid_alpha["Country/Region"] == country2].plot(x = "Date", y = "Confirmed")

country3 = 'Thailand'

covid_alpha[covid_alpha["Country/Region"] == country3].plot(x = "Date", y = "Confirmed")

country4 = 'United Kingdom'

covid_alpha[covid_alpha["Country/Region"] == country4].plot(x = "Date", y = "Confirmed")

country5 = 'Malaysia'

covid_alpha[covid_alpha["Country/Region"] == country5].plot(x = "Date", y = "Confirmed")

country6 = 'India'

covid_alpha[covid_alpha["Country/Region"] == country6].plot(x = "Date", y = "Confirmed")

country7 = 'Singapore'

covid_alpha[covid_alpha["Country/Region"] == country7].plot(x = "Date", y = "Confirmed")

country8 = 'Canada'

covid_alpha[covid_alpha["Country/Region"] == country8].plot(x = "Date", y = "Confirmed")

country9 = 'Philippines'

covid_alpha[covid_alpha["Country/Region"] == country9].plot(x = "Date", y = "Confirmed")

country10 = 'France'

covid_alpha[covid_alpha["Country/Region"] == country10].plot(x = "Date", y = "Confirmed")

# %%
from fbprophet import Prophet

# %%
from prophet.plot import add_changepoints_to_plot

# %%
from fbprophet.plot import add_changepoints_to_plot

# %%
# !pip install --upgrade plotly
# Out:
# Requirement already up-to-date: plotly in c:\users\utilisateur\anaconda3\lib\site-packages (5.4.0)
# ...

# %%
df = pd.DataFrame()
df['ds'] = pd.to_datetime(covid_alpha['Date'])
df['y'] = covid_alpha['Confirmed']

df.tail()
# Out:
#               ds      y
# 38815 2021-01-07  655.0
# 38816 2021-01-08    5.0
# 38817 2021-01-09   10.0
# 38818 2021-01-10  214.0
# 38819 2021-01-11  214.0

# %%
plt.style.use('fivethirtyeight')
ax = df.set_index('ds').plot(figsize=(12, 8))
ax.set_ylabel('Confirmed')#('Monthly Number of Airline Passengers')
ax.set_xlabel('Date') #number of flight daily
# Out:
# Text(0.5, 0, 'Date')

# %%
prophet = Prophet(seasonality_mode = 'multiplicative', yearly_seasonality=False, daily_seasonality=True, weekly_seasonality=True, interval_width=0.95)
prophet.fit(df)
future_dates = prophet.make_future_dataframe(periods=75, freq='d')
future_dates.tail()

# %%
forecast = prophet.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
prophet = Prophet(
                  yearly_seasonality=False,
                  weekly_seasonality=True,
                  daily_seasonality=False,
                  holidays=None,
                  seasonality_mode='multiplicative',
                  seasonality_prior_scale=10,
                  holidays_prior_scale=10,
                  changepoint_prior_scale=.05,
                  mcmc_samples=0
                 ).add_seasonality(name='yearly',
                                    period=365.25,
                                    fourier_order=3,
                                    prior_scale=10,
                                    mode='additive')

prophet.add_regressor('Origin')

prophet.fit(df['ds'])
future = prophet.make_future_dataframe(periods=75, freq='D')
future['Origin'] = covid_alpha_left['Origin']

forecast = prophet.predict(future)
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.show()
fig2 = prophet.plot_components(forecast)
plt.show()

# %%
#Additional Regressor
pro_regressor= Prophet()
pro_regressor.add_regressor('type')
pro_regressor.add_regressor('Total Volume')
pro_regressor.add_regressor('4046')
pro_regressor.add_regressor('4225')
pro_regressor.add_regressor('4770')
pro_regressor.add_regressor('Small Bags')

# %%
df['ds'] = pd.to_datetime(covid_alpha_left['Date'])
